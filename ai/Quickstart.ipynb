# %% [markdown]
# # Projektowanie algorytmów i metody szcztucznej inteligencji

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# 1. Demonstracja działania Jupyter notebook

# %%
x = np.arange(0, 1, 0.01)

fig = plt.figure()
ax = fig.add_subplot(212)
ax.plot(x, np.sin(2*2*np.pi*x))
